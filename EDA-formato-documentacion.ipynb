# %%
import pandas as pd
from src.tolookandcompare import to_doc_headtail, to_doc_info, transform_info, transform_headtail

# %%
df = pd.read_csv('files/World_Happiness_Report_limpio_sin_imputar.csv', dtype={'Country Name': 'object'})

# %%
transform_info(df,'Regional Indicator')
# Out:
# Valores únicos: 10
# Número de registros: 2199
# Valores nulos: 112
# Registros duplicados: 2189
# dtype: object
# ----------------
#
# Porcentajes:
# Regional Indicator
# Sub-Saharan Africa                    20.15
# Latin America and Caribbean           14.60
# Western Europe                        13.78
# Central and Eastern Europe            10.96
# Middle East and North Africa           9.28
# Commonwealth of Independent States     8.55
# Southeast Asia                         6.00
# NaN                                    5.09
# South Asia                             4.41
# East Asia                              4.18
# North America and ANZ                  3.00
# Name: proportion, dtype: float64
#
# Estadísticas descriptivas
# ---------------------------------
# Media: nan
# Mediana: nan
# Moda: nan
# c:\Users\Claudia\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
# ...

# %%
to_doc_info(df, 'Regional Indicator')
# Out:
# |    dtype: float64  |   Regional Indicator   |
# |-----------|---------------|
# ||
# ||nan  100.0
# ||<br>
# ||**Media:** nan
# ||**Mediana:** nan
# ||**Moda:** nan
# ||<br>
# ||Valores únicos: **0**
# ||Número de registros: **2199**
# ||Valores nulos: **2199**
# ||Registros duplicados: **2199**|
# ---
# c:\Users\Claudia\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
to_doc_info(df, 'Regional Indicator')
# Out:
# |    dtype: float64  |   Regional Indicator   |
# |-----------|---------------|
# ||
# ||nan  100.0
# ||<br>
# ||**Media:** nan
# ||**Mediana:** nan
# ||**Moda:** nan
# ||<br>
# ||Valores únicos: **0**
# ||Número de registros: **2199**
# ||Valores nulos: **2199**
# ||Registros duplicados: **2199**|
# ---
# c:\Users\Claudia\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
to_doc_info(df, 'Year')
# Out:
# |    dtype: int64  |   Year   |
# |-----------|---------------|
# ||
# ||2017  6.68
# ||2011  6.64
# ||2014  6.55
# ||2019  6.5
# ||2015  6.46
# ||2012  6.41
# ||2018  6.41
# ||2016  6.41
# ||2013  6.18
# ||2010  5.64
# ||2021  5.55
# ||2020  5.28
# ||2022  5.18
# ||2009  5.18
# ||2008  5.0
# ||2007  4.64
# ||2006  4.05
# ||2005  1.23
# ||<br>
# ||**Media:** 2014.1614370168259
# ||**Mediana:** 2014.0
# ||**Moda:** 2017.0
# ||<br>
# ||Valores únicos: **18**
# ||Número de registros: **2199**
# ||Valores nulos: **0**
# ||Registros duplicados: **2181**|
# ---

# %%
to_doc_headtail(df, 'Confidence In National Government')
# Out:
# |    dtype: float64  |   Confidence In National Government   |
# |-----------|---------------|
# ||
# ||**Top 5:**
# ||nan  16.42%
# ||0.611545205  0.05%
# ||0.299357414  0.05%
# ||0.307385713  0.05%
# ||0.435440153  0.05%
# ||**Bottom 5:**
# ||<br>
# ||0.387677372  0.05%
# ||0.344929039  0.05%
# ||0.263296992  0.05%
# ||0.267581195  0.05%
# ||0.61207211  0.05%
# ||<br>
# ||**Media:** 0.4839991736360174
# ||**Mediana:** 0.46713982499999995
# ||**Moda:** 0.06876874
# ||<br>
# ||Valores únicos: **1838**
# ||Número de registros: **2199**
# ||Valores nulos: **361**
# ||Registros duplicados: **361**|
# ---
